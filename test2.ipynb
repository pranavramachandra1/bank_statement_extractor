# %%
from pdfprocessor import PDFProcessor

# %%
path = "pdfs/BBT-Bank-Statement-EVERGREEN 6.17.2020-1-1.pdf"

p = PDFProcessor()

csvs = p.process(path)
csvs
# Out:
# extracted text
# processed data
# {'Account Summary': 'Previous Balance as of 05/18/2020,Checks,"Other withdrawals, debits and service charges","Deposits, credits and interest",New Balance as of 06/17/2020,Average Posted Balance in Statement Cycle\n"$2,074.21",-701.39,"-6,242.34","+5,834.32",$964.80,"$1,048.00"\n',
#  'Checks': 'Date,Check #,Amount ($)\n05/26,1401,450.00\n06/05,*965025,101.39\n06/09,985026,150.00\n',
# ...

# %%
csvs.keys()
# Out:
# dict_keys(['Account Summary', 'Checks', 'Other Withdrawals, Debits and Service Charges', 'Deposits, Credits and Interest', 'Savings Account Summary', 'Savings Account Interest Summary', 'Other Withdrawals, Debits and Service Charges - Savings Account'])

# %%
csvs['Account Summary']
# Out:
# 'Previous Balance as of 05/18/2020,Checks,"Other withdrawals, debits and service charges","Deposits, credits and interest",New Balance as of 06/17/2020,Average Posted Balance in Statement Cycle\n"$2,074.21",-701.39,"-6,242.34","+5,834.32",$964.80,"$1,048.00"\n'
