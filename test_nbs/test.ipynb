# %%
import pdfplumber
import google.generativeai as genai
import typing_extensions as typing
import json

# %%
def extract_text_from_pdf(pdf_file_path: str) -> str:
    with pdfplumber.open(pdf_file_path) as pdf:
        text = ""
        for page in pdf.pages:
            text += page.extract_text() + "\n"
        return text

# %%
path = "pdfs/BBT-Bank-Statement-EVERGREEN 6.17.2020-1-1.pdf"

text = extract_text_from_pdf(path)
with open("output.txt", "w") as file:
    file.write(extract_text_from_pdf(path))

# %%
model = genai.GenerativeModel("gemini-1.5-flash")

# %%
text
# Out:
# 'Page 1 of 5 06/17/20\nDC 1090001004290\n999-99-99-99 16769 3 C 001 11 S 66 002\nEVERGREEN SUPPLIERS\n88 SUNRISE BLVD\nRIVERSIDE, CA 92506\nYour consolidated statement\nContact us\n(600) BANK-BBT or\nFor 06/17/2020 BBT.com\n(800) 226-5228\nDo more with digital banking\nBank without having to leave home. Check your account balances, make transfers, pay bills and deposit checks with your mobile device. If\nyou are not enrolled in digital banking, it only lakes a minute Gel started today at BBT.com/U.\nTruist Bank, Member FDIC. To learn more, visit BBT.com/Truist. ©2020 Truist Financial Corporation.\nIf you are traveling outside of the USA and have concerns about accessing your account while you are traveling, please contact your\nBranch Banker or call us at 800-BANK BBT.\nSummary of your accounts\nACCOUNT NAME ACCOUNT NUMBER BALANCE ($) DETAILS ON\nBRIGHT BANKING 1090001004290 964.80 page 1\nTotal checking and money market savings accounts $964.80\nBRIGHT BANKING 1090001004290 7.60 page 3\nTotal savings accounts $7.60\nChecking and money market savings accounts\n■ BRIGHT BANKING 1090001004290\nAccount summary\nYour previous balance as of 05/18/2020 $2,074,21\nChecks - 701.39\nOther withdrawals, debits and service charges - 6,242.34\nDeposits, credits and interest + 5,834.32\nYour new balance as of 06/17/2020 = $964.80\nAverage Posted Balance in Statement Cycle $1,048.00\nChecks\nDATE CHECK # AMOUNT ($) DATE CHECK # AMOUNT ($) DATE CHECK # AMOUNT ($)\n05/26 1401 450.00 06/05 *965025 101.39 06/09 985026 150.00\n* indicates a skip in sequential check numbers above this item Total checks = $701.39\n■ Page 1 of 5\n0000667\nBRIGHT BANKING 1090001004290 (continued)\nOther withdrawals, debits and service charges\nDATE DESCRIPTION AMOUNT ($)\n05/19 BB&T ONLINE BILL PAYMENT ONLINE PMT CREDIT CARD CKF768752662POS 100.00\n05/19 BB&T ONLINE BILL PAYMENT ONLINE PMT FIRST PROGRESS CKF768752662POS 100.00\n05/19 BB&T ONLINE BILL PAYMENT ONLINE PMT MERRICK BANK CKF768752662POS 100.00\n05/19 BB&T ONLINE BILL PAYMENT ONLINE PMT CREDIT ONE BANK CKF768752662POS 200.00\n05/19 DEBIT CARD PURCHASE-PIN 05-18-20 WASHINGTON DC 6901 SAFEWAY 2808 27.21\n05/19 CC PMT LEADBANKSELFLEND 6438 RICARDO BROUGHTON 62.62\n05/20 INTERNET PAYMENT PAYMENT FSB BLAZE 518213010852770 75.00\n05/21 DEBIT CARD PURCHASE SHELL OIL 10000581 05-19 WASHINGTON DC 6901 1.99\n05/21 INTERNET PAYMENT PAYMENT FIRST SAVINGS 543360180270219 100.00\n05/22 DEBIT CARD PURCHASE SHELL OIL 57525762 05-20 BALTIMORE MD 6901 28.00\n05/22 DEBIT CARD PURCHASE PREMIER Bankcard 05-21 605-3573440 SD 6901 335.00\n05/22 DEBIT CARD PURCHASE-PIN 05-22-20 BALTIMORE MD 6901 ROYAL FARMS 138 16.60\n05/26 DEBIT CARD PURCHASE-PIN 05-22-20 BALTIMORE MD 6901 RUSSELL STREET C 20.00\n05/26 DEBIT CARD PURCHASE-PIN 05-25-20 CLINTON MD 6901 CVS/PHARMACY #01 01491--8 26.67\n05/26 PAYMENT LEGACY VISA PYMT 5169 BROUGHTON.RICARDO D 56.50\n05/26 DEBIT CARD PURCHASE-PIN 05-28-20 BALTIMORE MD 6901 RUSSELL STREET C 24.50\n06/01 DEBIT CARD PURCHASE Q & Q CLEANERS 05-29 WASHINGTON DC 6901 47.55\n06/01 DEBIT CARD PURCHASE-PIN 05-29-20 WASHINGTON DC 6901 SAFEWAY 2808 27.34\n06/01 DEBIT CARD RECURRING PYMT METROPCS AUTO PAY 05-30 888-863-8768 WA 6901 60.00\n06/01 DEBIT CARD PURCHASE-PIN 05-30-20 WASHINGTON DC 6901 1601 NEW YORK AVE 11,99\n06/01 DEBIT CARD PURCHASE FORESTVILLE EXXON 05-30 FORESTVILLE MD 6901 10.00\n06/01 DEBIT CARD PURCHASE COLDSTONE CREAMERY 05-30 WALDORF MD 6901 28.93\n06/01 DEBIT CARD PURCHASE-PIN 05-30-20 WALDORF MD 6901 SAFEWAY 0105 15.00\n06/01 DEBIT CARD PURCHASE-PIN 05-30-20 FORESTVILLE MD 6901 SHOPPERS FOOD/PHARM 2669 69.43\n06/01 DEBIT CARD PURCHASE RENTSPREE LLC 05-31 323-515-7757 CA 6901 30.00\n06/01 DEBIT CARD PURCHASE SHOPPERS FOOD / PH 05-31 FORESTVILLE MD 6901 8.99\n06/01 DEBIT CARD PURCHASE-PIN 06-01-20 FORESTVILLE MD 6901 7-ELEVEN 4.23\n06/01 CC PMT LEADBANKSELFLEND 5387 RICARDO BROUGHTON 64.87\n06/01 INTERNET PAYMENT PAYMENT FSB BLAZE 51 821 301 0852770 102.78\n06/02 BB&T ONLINE BILL PAYMENT ONLINE ...

# %%
prompt = """The following text is a bank statement containing structured tables of transaction data along with other text. Extract all the tables from the text. For each table:
1. Assign a descriptive title based on the content of the table (e.g., "Account Summary", "Checks", "Deposits and Credits").
2. Format the table as JSON with the following structure:
   {
       "title": "Table Title",
       "header": ["Column1", "Column2", "Column3"],
       "rows": [
           ["Row1Value1", "Row1Value2", "Row1Value3"],
           ["Row2Value1", "Row2Value2", "Row2Value3"]
       ]
   }
3. If multiple tables exist, return them as a list of JSON objects under the key `"tables"`. Ensure each table has a unique title.
   
Text data from the bank statement:"""

full_prompt = f"{prompt}\n\n{text}"
full_prompt
# Out:
# 'The following text is a bank statement containing structured tables of transaction data along with other text. Extract all the tables from the text. For each table:\n1. Assign a descriptive title based on the content of the table (e.g., "Account Summary", "Checks", "Deposits and Credits").\n2. Format the table as JSON with the following structure:\n   {\n       "title": "Table Title",\n       "header": ["Column1", "Column2", "Column3"],\n       "rows": [\n           ["Row1Value1", "Row1Value2", "Row1Value3"],\n           ["Row2Value1", "Row2Value2", "Row2Value3"]\n       ]\n   }\n3. If multiple tables exist, return them as a list of JSON objects under the key `"tables"`. Ensure each table has a unique title.\n   \nText data from the bank statement:\n\nPage 1 of 5 06/17/20\nDC 1090001004290\n999-99-99-99 16769 3 C 001 11 S 66 002\nEVERGREEN SUPPLIERS\n88 SUNRISE BLVD\nRIVERSIDE, CA 92506\nYour consolidated statement\nContact us\n(600) BANK-BBT or\nFor 06/17/2020 BBT.com\n(800) 226-5228\nDo more with digital banking\nBank without having to leave home. Check your account balances, make transfers, pay bills and deposit checks with your mobile device. If\nyou are not enrolled in digital banking, it only lakes a minute Gel started today at BBT.com/U.\nTruist Bank, Member FDIC. To learn more, visit BBT.com/Truist. ©2020 Truist Financial Corporation.\nIf you are traveling outside of the USA and have concerns about accessing your account while you are traveling, please contact your\nBranch Banker or call us at 800-BANK BBT.\nSummary of your accounts\nACCOUNT NAME ACCOUNT NUMBER BALANCE ($) DETAILS ON\nBRIGHT BANKING 1090001004290 964.80 page 1\nTotal checking and money market savings accounts $964.80\nBRIGHT BANKING 1090001004290 7.60 page 3\nTotal savings accounts $7.60\nChecking and money market savings accounts\n■ BRIGHT BANKING 1090001004290\nAccount summary\nYour previous balance as of 05/18/2020 $2,074,21\nChecks - 701.39\nOther withdrawals, debits and service charges - 6,242.34\nDeposits, credits and interest + 5,834.32\nYour new balance as of 06/17/2020 = $964.80\nAverage Posted Balance in Statement Cycle $1,048.00\nChecks\nDATE CHECK # AMOUNT ($) DATE CHECK # AMOUNT ($) DATE CHECK # AMOUNT ($)\n05/26 1401 450.00 06/05 *965025 101.39 06/09 985026 150.00\n* indicates a skip in sequential check numbers above this item Total checks = $701.39\n■ Page 1 of 5\n0000667\nBRIGHT BANKING 1090001004290 (continued)\nOther withdrawals, debits and service charges\nDATE DESCRIPTION AMOUNT ($)\n05/19 BB&T ONLINE BILL PAYMENT ONLINE PMT CREDIT CARD CKF768752662POS 100.00\n05/19 BB&T ONLINE BILL PAYMENT ONLINE PMT FIRST PROGRESS CKF768752662POS 100.00\n05/19 BB&T ONLINE BILL PAYMENT ONLINE PMT MERRICK BANK CKF768752662POS 100.00\n05/19 BB&T ONLINE BILL PAYMENT ONLINE PMT CREDIT ONE BANK CKF768752662POS 200.00\n05/19 DEBIT CARD PURCHASE-PIN 05-18-20 WASHINGTON DC 6901 SAFEWAY 2808 27.21\n05/19 CC PMT LEADBANKSELFLEND 6438 RICARDO BROUGHTON 62.62\n05/20 INTERNET PAYMENT PAYMENT FSB BLAZE 518213010852770 75.00\n05/21 DEBIT CARD PURCHASE SHELL OIL 10000581 05-19 WASHINGTON DC 6901 1.99\n05/21 INTERNET PAYMENT PAYMENT FIRST SAVINGS 543360180270219 100.00\n05/22 DEBIT CARD PURCHASE SHELL OIL 57525762 05-20 BALTIMORE MD 6901 28.00\n05/22 DEBIT CARD PURCHASE PREMIER Bankcard 05-21 605-3573440 SD 6901 335.00\n05/22 DEBIT CARD PURCHASE-PIN 05-22-20 BALTIMORE MD 6901 ROYAL FARMS 138 16.60\n05/26 DEBIT CARD PURCHASE-PIN 05-22-20 BALTIMORE MD 6901 RUSSELL STREET C 20.00\n05/26 DEBIT CARD PURCHASE-PIN 05-25-20 CLINTON MD 6901 CVS/PHARMACY #01 01491--8 26.67\n05/26 PAYMENT LEGACY VISA PYMT 5169 BROUGHTON.RICARDO D 56.50\n05/26 DEBIT CARD PURCHASE-PIN 05-28-20 BALTIMORE MD 6901 RUSSELL STREET C 24.50\n06/01 DEBIT CARD PURCHASE Q & Q CLEANERS 05-29 WASHINGTON DC 6901 47.55\n06/01 DEBIT CARD PURCHASE-PIN 05-29-20 WASHINGTON DC 6901 SAFEWAY 2808 27.34\n06/01 DEBIT CARD RECURRING PYMT METROPCS AUTO PAY 05-30 888-863-8768 WA 6901 60.00\n06/01 DEBIT CARD PURCHASE-PI ...

# %%
class ExtractedData(typing.TypedDict):
    date: str
    name_of_transaction: str
    amount: float

# %%
result = model.generate_content(
    full_prompt,
    generation_config=genai.GenerationConfig(
        response_mime_type="application/json"
    )
)
print(result)
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "{\"tables\": [{\"title\": \"Account Summary\", \"header\": [\"Previous Balance as of 05/18/2020\", \"Checks\", \"Other Withdrawals, Debits and Service Charges\", \"Deposits, Credits and Interest\", \"New Balance as of 06/17/2020\", \"Average Posted Balance in Statement Cycle\"], \"rows\": [[\"$2,074.21\", \"-701.39\", \"-6,242.34\", \"+5,834.32\", \"$964.80\", \"$1,048.00\"]]}, {\"title\": \"Checks\", \"header\": [\"Date\", \"Check #\", \"Amount ($)\"], \"rows\": [[\"05/26\", \"1401\", \"450.00\"], [\"06/05\", \"*965025\", \"101.39\"], [\"06/09\", \"985026\", \"150.00\"]]}, {\"title\": \"Other Withdrawals, Debits and Service Charges\", \"header\": [\"Date\", \"Description\", \"Amount ($)\"], \"rows\": [[\"05/19\", \"BB&T ONLINE BILL PAYMENT ONLINE PMT CREDIT CARD CKF768752662POS\", \"100.00\"], [\"05/19\", \"BB&T ONLINE BILL PAYMENT ONLINE PMT FIRST PROGRESS CKF768752662POS\", \"100.00\"], [\"05/19\", \"BB&T ONLINE BILL PAYMENT ONLINE PMT MERRICK BANK CKF768752662POS\", \"100.00\"], [\"05/19\", \"BB&T ONLINE BILL PAYMENT ONLINE PMT CREDIT ONE BANK CKF768752662POS\", \"200.00\"], [\"05/19\", \"DEBIT CARD PURCHASE-PIN 05-18-20 WASHINGTON DC 6901 SAFEWAY 2808\", \"27.21\"], [\"05/19\", \"CC PMT LEADBANKSELFLEND 6438 RICARDO BROUGHTON\", \"62.62\"], [\"05/20\", \"INTERNET PAYMENT PAYMENT FSB BLAZE 518213010852770\", \"75.00\"], [\"05/21\", \"DEBIT CARD PURCHASE SHELL OIL 10000581 05-19 WASHINGTON DC 6901\", \"1.99\"], [\"05/21\", \"INTERNET PAYMENT PAYMENT FIRST SAVINGS 543360180270219\", \"100.00\"], [\"05/22\", \"DEBIT CARD PURCHASE SHELL OIL 57525762 05-20 BALTIMORE MD 6901\", \"28.00\"], [\"05/22\", \"DEBIT CARD PURCHASE PREMIER Bankcard 05-21 605-3573440 SD 6901\", \"335.00\"], [\"05/22\", \"DEBIT CARD PURCHASE-PIN 05-22-20 BALTIMORE MD 6901 ROYAL FARMS 138\", \"16.60\"], [\"05/26\", \"DEBIT CARD PURCHASE-PIN 05-22-20 BALTIMORE MD 6901 RUSSELL STREET C\", \"20.00\"], [\"05/26\", \"DEBIT CARD PURCHASE-PIN 05-25-20 CLINTON MD 6901 CVS/PHARMACY #01 01491--8\", \"26.67\"], [\"05/26\", \"PAYMENT LEGACY VISA PYMT 5169 BROUGHTON.RICARDO D\", \"56.50\"], [\"05/26\", \"DEBIT CARD PURCHASE-PIN 05-28-20 BALTIMORE MD 6901 RUSSELL STREET C\", \"24.50\"], [\"06/01\", \"DEBIT CARD PURCHASE Q & Q CLEANERS 05-29 WASHINGTON DC 6901\", \"47.55\"], [\"06/01\", \"DEBIT CARD PURCHASE-PIN 05-29-20 WASHINGTON DC 6901 SAFEWAY 2808\", \"27.34\"], [\"06/01\", \"DEBIT CARD RECURRING PYMT METROPCS AUTO PAY 05-30 888-863-8768 WA 6901\", \"60.00\"], [\"06/01\", \"DEBIT CARD PURCHASE-PIN 05-30-20 WASHINGTON DC 6901 1601 NEW YORK AVE\", \"11.99\"], [\"06/01\", \"DEBIT CARD PURCHASE FORESTVILLE EXXON 05-30 FORESTVILLE MD 6901\", \"10.00\"], [\"06/01\", \"DEBIT CARD PURCHASE COLDSTONE CREAMERY 05-30 WALDORF MD 6901\", \"28.93\"], [\"06/01\", \"DEBIT CARD PURCHASE-PIN 05-30-20 WALDORF MD 6901 SAFEWAY 0105\", \"15.00\"], [\"06/01\", \"DEBIT CARD PURCHASE-PIN 05-30-20 FORESTVILLE MD 6901 SHOPPERS FOOD/PHARM 2669\", \"69.43\"], [\"06/01\", \"DEBIT CARD PURCHASE RENTSPREE LLC 05-31 323-515-7757 CA 6901\", \"30.00\"], [\"06/01\", \"DEBIT CARD PURCHASE SHOPPERS FOOD / PH 05-31 FORESTVILLE MD 6901\", \"8.99\"], [\"06/01\", \"DEBIT CARD PURCHASE-PIN 06-01-20 FORESTVILLE MD 6901 7-ELEVEN\", \"4.23\"], [\"06/01\", \"CC PMT LEADBANKSELFLEND 5387 RICARDO BROUGHTON\", \"64.87\"], [\"06/01\", \"INTERNET PAYMENT PAYMENT FSB BLAZE 51 821 301 0852770\", \"102.78\"], [\"06/02\", \"BB&T ONLINE BILL PAYMENT ONLINE PMT MERRICK BANK CKF768752662POS\", \"92.83\"], [\"06/02\", \"BB&T ONLINE BILL PAYMENT ONLINE PMT CREDIT ONE BANK CKF768752662POS\", \"150.00\"], [\"06/02\", \"BB&T ONLINE BILL PAYMENT ONLINE PMT FIRST PROGRESS CKF768752662POS\", \"150.00\"], [\"06/02\", \"DEBIT CARD PURCHASE-PIN 06-01-20 WASHINGTON DC 6901 SAFEWAY 2808\", \"24.31\"], [\"06/02\", \"BB&T 24 CASH WITHDRAWAL 06-02-20 6901 DC-KENYON SQUARE WASHINGTON DC\", \"160.00\"], [\"06/02\", \"TELEPHONE PAYMENT PAYBYPHONE CREDITCARD PYMNT 1361403418\", \"138.72\"], [\"06/03\", \"DEBIT CARD PURC ...
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0015406296969111364
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 7102,
#         "candidates_token_count": 4759,
#         "total_token_count": 11861
#       }
#     }),
# )

# %%
text_result = json.loads(result.candidates[0].content.parts[0].text)
print(text_result)
# Out:
# {'tables': [{'title': 'Account Summary', 'header': ['Previous Balance as of 05/18/2020', 'Checks', 'Other Withdrawals, Debits and Service Charges', 'Deposits, Credits and Interest', 'New Balance as of 06/17/2020', 'Average Posted Balance in Statement Cycle'], 'rows': [['$2,074.21', '-701.39', '-6,242.34', '+5,834.32', '$964.80', '$1,048.00']]}, {'title': 'Checks', 'header': ['Date', 'Check #', 'Amount ($)'], 'rows': [['05/26', '1401', '450.00'], ['06/05', '*965025', '101.39'], ['06/09', '985026', '150.00']]}, {'title': 'Other Withdrawals, Debits and Service Charges', 'header': ['Date', 'Description', 'Amount ($)'], 'rows': [['05/19', 'BB&T ONLINE BILL PAYMENT ONLINE PMT CREDIT CARD CKF768752662POS', '100.00'], ['05/19', 'BB&T ONLINE BILL PAYMENT ONLINE PMT FIRST PROGRESS CKF768752662POS', '100.00'], ['05/19', 'BB&T ONLINE BILL PAYMENT ONLINE PMT MERRICK BANK CKF768752662POS', '100.00'], ['05/19', 'BB&T ONLINE BILL PAYMENT ONLINE PMT CREDIT ONE BANK CKF768752662POS', '200.00'], ['05/19', 'DEBIT CARD PURCHASE-PIN 05-18-20 WASHINGTON DC 6901 SAFEWAY 2808', '27.21'], ['05/19', 'CC PMT LEADBANKSELFLEND 6438 RICARDO BROUGHTON', '62.62'], ['05/20', 'INTERNET PAYMENT PAYMENT FSB BLAZE 518213010852770', '75.00'], ['05/21', 'DEBIT CARD PURCHASE SHELL OIL 10000581 05-19 WASHINGTON DC 6901', '1.99'], ['05/21', 'INTERNET PAYMENT PAYMENT FIRST SAVINGS 543360180270219', '100.00'], ['05/22', 'DEBIT CARD PURCHASE SHELL OIL 57525762 05-20 BALTIMORE MD 6901', '28.00'], ['05/22', 'DEBIT CARD PURCHASE PREMIER Bankcard 05-21 605-3573440 SD 6901', '335.00'], ['05/22', 'DEBIT CARD PURCHASE-PIN 05-22-20 BALTIMORE MD 6901 ROYAL FARMS 138', '16.60'], ['05/26', 'DEBIT CARD PURCHASE-PIN 05-22-20 BALTIMORE MD 6901 RUSSELL STREET C', '20.00'], ['05/26', 'DEBIT CARD PURCHASE-PIN 05-25-20 CLINTON MD 6901 CVS/PHARMACY #01 01491--8', '26.67'], ['05/26', 'PAYMENT LEGACY VISA PYMT 5169 BROUGHTON.RICARDO D', '56.50'], ['05/26', 'DEBIT CARD PURCHASE-PIN 05-28-20 BALTIMORE MD 6901 RUSSELL STREET C', '24.50'], ['06/01', 'DEBIT CARD PURCHASE Q & Q CLEANERS 05-29 WASHINGTON DC 6901', '47.55'], ['06/01', 'DEBIT CARD PURCHASE-PIN 05-29-20 WASHINGTON DC 6901 SAFEWAY 2808', '27.34'], ['06/01', 'DEBIT CARD RECURRING PYMT METROPCS AUTO PAY 05-30 888-863-8768 WA 6901', '60.00'], ['06/01', 'DEBIT CARD PURCHASE-PIN 05-30-20 WASHINGTON DC 6901 1601 NEW YORK AVE', '11.99'], ['06/01', 'DEBIT CARD PURCHASE FORESTVILLE EXXON 05-30 FORESTVILLE MD 6901', '10.00'], ['06/01', 'DEBIT CARD PURCHASE COLDSTONE CREAMERY 05-30 WALDORF MD 6901', '28.93'], ['06/01', 'DEBIT CARD PURCHASE-PIN 05-30-20 WALDORF MD 6901 SAFEWAY 0105', '15.00'], ['06/01', 'DEBIT CARD PURCHASE-PIN 05-30-20 FORESTVILLE MD 6901 SHOPPERS FOOD/PHARM 2669', '69.43'], ['06/01', 'DEBIT CARD PURCHASE RENTSPREE LLC 05-31 323-515-7757 CA 6901', '30.00'], ['06/01', 'DEBIT CARD PURCHASE SHOPPERS FOOD / PH 05-31 FORESTVILLE MD 6901', '8.99'], ['06/01', 'DEBIT CARD PURCHASE-PIN 06-01-20 FORESTVILLE MD 6901 7-ELEVEN', '4.23'], ['06/01', 'CC PMT LEADBANKSELFLEND 5387 RICARDO BROUGHTON', '64.87'], ['06/01', 'INTERNET PAYMENT PAYMENT FSB BLAZE 51 821 301 0852770', '102.78'], ['06/02', 'BB&T ONLINE BILL PAYMENT ONLINE PMT MERRICK BANK CKF768752662POS', '92.83'], ['06/02', 'BB&T ONLINE BILL PAYMENT ONLINE PMT CREDIT ONE BANK CKF768752662POS', '150.00'], ['06/02', 'BB&T ONLINE BILL PAYMENT ONLINE PMT FIRST PROGRESS CKF768752662POS', '150.00'], ['06/02', 'DEBIT CARD PURCHASE-PIN 06-01-20 WASHINGTON DC 6901 SAFEWAY 2808', '24.31'], ['06/02', 'BB&T 24 CASH WITHDRAWAL 06-02-20 6901 DC-KENYON SQUARE WASHINGTON DC', '160.00'], ['06/02', 'TELEPHONE PAYMENT PAYBYPHONE CREDITCARD PYMNT 1361403418', '138.72'], ['06/03', 'DEBIT CARD PURCHASE-PIN 06-02-20 BALTIMORE MD 6901 ROYAL FARMS 138', '32.60'], ['06/03', 'PAYMENTS LEADBANKSELFLEND 1496 RICARDO BROUGHTON', '25.00'], ['06/03', 'INTERNET PAYMENT ePay Fortiva MC PMT FORTIVA MC PMT', '98.09'], ['06/03', 'INTERNET PAYMENT Payment Credit One Bank 42144109', '109.00'], ['06/04', 'DEBIT CARD PURCHASE PR ...

# %%
text_result
# Out:
# {'tables': [{'header': ['DATE', 'CHECK #', 'AMOUNT ($)'],
#    'rows': [['04/26', '1401', '450.00'],
#     ['05/05', '*965025', '101.39'],
#     ['05/09', '985026', '150.00']]},
#   {'header': ['DATE', 'DESCRIPTION', 'AMOUNT ($)'],
#    'rows': [['04/19',
#      'BB&T ONLINE BILL PAYMENT ONLINE PMT CREDIT CARD CKF768752662POS',
#      '100.00'],
#     ['04/19',
#      'BB&T ONLINE BILL PAYMENT ONLINE PMT FIRST PROGRESS CKF768752662POS',
#      '100.00'],
#     ['04/19',
#      'BB&T ONLINE BILL PAYMENT ONLINE PMT MERRICK BANK CKF768752662POS',
#      '100.00'],
#     ['04/19',
#      'BB&T ONLINE BILL PAYMENT ONLINE PMT CREDIT ONE BANK CKF768752662POS',
#      '200.00'],
#     ['04/19',
#      'DEBIT CARD PURCHASE-PIN 05-18-20 WASHINGTON DC 6901 SAFEWAY 2808',
#      '27.21'],
#     ['04/19', 'CC PMT LEADBANKSELFLEND 6438 RICARDO BROUGHTON', '62.62'],
#     ['04/20', 'INTERNET PAYMENT PAYMENT FSB BLAZE 518213010852770', '75.00'],
#     ['04/21',
#      'DEBIT CARD PURCHASE SHELL OIL 10000581 05-19 WASHINGTON DC 6901',
#      '1.99'],
#     ['04/21',
#      'INTERNET PAYMENT PAYMENT FIRST SAVINGS 543360180270219',
#      '100.00'],
#     ['04/22',
#      'DEBIT CARD PURCHASE SHELL OIL 57525762 05-20 BALTIMORE MD 6901',
#      '28.00'],
#     ['04/22',
#      'DEBIT CARD PURCHASE PREMIER Bankcard 05-21 605-3573440 SD 6901',
#      '335.00'],
#     ['04/22',
#      'DEBIT CARD PURCHASE-PIN 05-22-20 BALTIMORE MD 6901 ROYAL FARMS 138',
#      '16.60'],
#     ['04/26',
#      'DEBIT CARD PURCHASE-PIN 05-22-20 BALTIMORE MD 6901 RUSSELL STREET C',
#      '20.00'],
#     ['04/26',
#      'DEBIT CARD PURCHASE-PIN 05-25-20 CLINTON MD 6901 CVS/PHARMACY #01 01491--8',
#      '26.67'],
#     ['04/26', 'PAYMENT LEGACY VISA PYMT 5169 BROUGHTON.RICARDO D', '56.50'],
#     ['04/26',
#      'DEBIT CARD PURCHASE-PIN 05-28-20 BALTIMORE MD 6901 RUSSELL STREET C',
#      '24.50'],
#     ['05/01',
#      'DEBIT CARD PURCHASE Q & Q CLEANERS 05-29 WASHINGTON DC 6901',
#      '47.55'],
#     ['05/01',
#      'DEBIT CARD PURCHASE-PIN 05-29-20 WASHINGTON DC 6901 SAFEWAY 2808',
#      '27.34'],
#     ['05/01',
#      'DEBIT CARD RECURRING PYMT METROPCS AUTO PAY 05-30 888-863-8768 WA 6901',
#      '60.00'],
#     ['05/01',
#      'DEBIT CARD PURCHASE-PIN 05-30-20 WASHINGTON DC 6901 1601 NEW YORK AVE',
#      '11.99'],
#     ['05/01',
#      'DEBIT CARD PURCHASE FORESTVILLE EXXON 05-30 FORESTVILLE MD 6901',
#      '10.00'],
#     ['05/01',
#      'DEBIT CARD PURCHASE COLDSTONE CREAMERY 05-30 WALDORF MD 6901',
#      '28.93'],
#     ['05/01',
#      'DEBIT CARD PURCHASE-PIN 05-30-20 WALDORF MD 6901 SAFEWAY 0105',
#      '15.00'],
#     ['05/01',
#      'DEBIT CARD PURCHASE-PIN 05-30-20 FORESTVILLE MD 6901 SHOPPERS FOOD/PHARM 2669',
#      '69.43'],
#     ['05/01',
#      'DEBIT CARD PURCHASE RENTSPREE LLC 05-31 323-515-7757 CA 6901',
#      '30.00'],
#     ['05/01',
#      'DEBIT CARD PURCHASE SHOPPERS FOOD / PH 05-31 FORESTVILLE MD 6901',
#      '8.99'],
#     ['05/01',
#      'DEBIT CARD PURCHASE-PIN 05-01-20 FORESTVILLE MD 6901 7-ELEVEN',
#      '4.23'],
#     ['05/01', 'CC PMT LEADBANKSELFLEND 5387 RICARDO BROUGHTON', '64.87'],
#     ['05/01',
#      'INTERNET PAYMENT PAYMENT FSB BLAZE 51 821 301 0852770',
#      '102.78'],
#     ['05/02',
#      'BB&T ONLINE BILL PAYMENT ONLINE PMT MERRICK BANK CKF768752662POS',
#      '92.83'],
#     ['05/02',
#      'BB&T ONLINE BILL PAYMENT ONLINE PMT CREDIT ONE BANK CKF768752662POS',
#      '150.00'],
#     ['05/02',
#      'BB&T ONLINE BILL PAYMENT ONLINE PMT FIRST PROGRESS CKF768752662POS',
#      '150.00'],
#     ['05/02',
#      'DEBIT CARD PURCHASE-PIN 05-01-20 WASHINGTON DC 6901 SAFEWAY 2808',
#      '24.31'],
#     ['05/02',
#      'BB&T 24 CASH WITHDRAWAL 05-02-20 6901 DC-KENYON SQUARE WASHINGTON DC',
#      '160.00'],
#     ['05/02',
#      'TELEPHONE PAYMENT PAYBYPHONE CREDITCARD PYMNT 1361403418',
#      '138.72'],
#     ['05/03',
#      'DEBIT CARD PURCHASE-PIN 05-02-20 BALTIMORE MD 6901 ROYAL FARMS 138',
#      '32.60'],
#     ['05/03', 'PAYMENTS LEADBANKSELFLEND 1496 RICARDO BROUGHTON', '25.00'],
#     ['05/03', 'INTERNET PAYMENT ePay Fortiva MC PMT FORTIVA MC PMT', '98.09'],
#     ['05/03', 'INTERNET PAYMENT Payment Credit One Bank 42144109', '109.00'],
#     ['05/04',
#      'DEBIT CARD PURCHASE PRICE BUSTERS FURN 05-02 BROOKLYN PARK MD 6901',
#      '200.00'],
#     ['05/04',
#      "DEBIT CARD PURCHASE AMZN Mktp US'MY9MU 05-03 Amzn.corn/bill WA 6901",
#      '57.18'],
#     ['05/04',
#      'BB&T ONLINE BILL PAYMENT ONLINE PMT FIRST PROGRESS CKF768752662POS',
#      '104.94'],
#     ['05/04',
#      'DEBIT CARD PURCHASE DOUBLE GOOD POPCOR 05-03 630-568-5544 IL 6901',
#      '51.45'],
#     ['05/04',
#      'DEBIT CARD PURCHASE-PIN 05-03-20 BALTIMORE MD 6901 ROYAL FARMS 138',
#      '12.60'],
#     ['05/04',
#      'DEBIT CARD PURCHASE-PIN 05-03-20 WASHINGTON DC 6901 SAFEWAY 2808',
#      '32.87'],
#     ['05/05',
#      'DEBIT CARD PURCHASE-PIN 05-04-20 BALTIMORE MD 6901 RUSSELL STREET C',
#      '25.00'],
#     ['05/05',
#      'DEBIT CARD PURCHASE-PIN 05-04-20 WASHINGTON DC 6901 SAFEWAY 2808',
#      '3.00'],
#     ['05/05',
#      'DEBIT CARD PURCHASE-PIN 05-04-20 WASHINGTON DC 6901 SAFEWAY 2808',
#      '4.22'],
#     ['05/05',
#      'RECURRING INTERNET PAYMENT DIRECTPAY CAPITAL ONE AUTO 005205270989798',
#      '403.88'],
#     ['05/08',
#      'DEBIT CARD PURCHASE Etsy.com 05-05 718-8557955 NY 6901',
#      '46.40'],
#     ['05/08',
#      'DEBIT CARD PURCHASE DASH IN #1501 - HA 05-05 BALTIMORE MD 6901',
#      '8.00'],
#     ['05/08',
#      'DEBIT CARD PURCHASE-PIN 05-05-20 BALTIMORE MD 6901 ROYAL FARMS 138',
#      '12.60'],
#     ['05/08',
#      'DEBIT CARD PURCHASE-PIN 05-05-20 CLINTON MD 6901 WAL-MART #2799',
#      '78.33'],
#     ['05/08',
#      'DEBIT CARD PURCHASE RENTLY.COM 05-05 888-340-6340 CA 6901',
#      '0.99'],
#     ['05/08',
#      'DEBIT CARD PURCHASE WENDYS #6535 05-05 WASHINGTON DC 6901',
#      '17.13'],
#     ['05/08',
#      'DEBIT CARD PURCHASE ROYAL FARMS #287 05-05 DISTRICT HEIG MD 6901',
#      '20.00'],
#     ['05/08',
#      'DEBIT CARD PURCHASE FAMILY DOLLAR #413 05-05 TEMPLE HILLS MD 6901',
#      '5.30'],
#     ['05/08',
#      'DEBIT CARD PURCHASE GOLDEN SKILLET 05-05 FORESTVILLE ME 6901',
#      '11.33'],
#     ['05/08',
#      'DEBIT CARD PURCHASE SAVE-A-LOT #533 05-05 FORESTVILLE MD 6901',
#      '24.63'],
#     ['05/08',
#      'DEBIT CARD PURCHASE NY CHICKEN AND GRI 05-07 DISTRICT HEIG MD 6901',
#      '22.77'],
#     ['05/08',
#      'DEBIT CARD PURCHASE-PIN 05-07-20 DISTRICT HEIG MD 6901 ROYAL FARMS #287',
#      '4.01'],
#     ['05/08',
#      'DEBIT CARD PURCHASE-PIN 05-07-20 DISTRICT HEIG MD 6901 ROYAL FARMS #287',
#      '10.00'],
#     ['05/08',
#      'DEBIT CARD PURCHASE PAYPAL*LATAPA2019 05-07 402-935-7733 CA 6901',
#      '36.78'],
#     ['05/08',
#      'INTERNET PAYMENT PAYMENT FIRST SAVINGS 543360180270219',
#      '0.90'],
#     ['05/09', 'INTERNET PAYMENT June Subsc Current kZJFJ6uPk56ybWC', '4.99'],
#     ['05/10',
#      'DEBIT CARD PURCHASE-PIN 05-09-20 BALTIMORE MD 6901 ROYAL FARMS 138',
#      '20.69'],
#     ['05/10',
#      'DEBIT CARD PURCHASE-PIN 05-09-20 WASHINGTON DC 6901 SAFEWAY 2808',
#      '6.99'],
#     ['05/11',
#      'DEBIT CARD PURCHASE-PIN 05-10-20 WASHINGTON DC 6901 SAFEWAY 2808',
#      '5.78'],
#     ['05/12',
#      'DEBIT CARD PURCHASE-PIN 05-12-20 BALTIMORE MD 6901 SHELL SERVICE STATION',
#      '32.37'],
#     ['05/12', '8662580165 VBS BetterDay 43in Ricardo Broughton', '203.05'],
#     ['05/12', '8662580165 VBS BetterDay 44pd Ricardo Broughton', '1149.69'],
#     ['05/15',
#      'DEBIT CARD PURCHASE SHELL OIL 57525762 05-11 BALTIMORE MD 6901',
#      '7.79'],
#     ['05/15',
#      'DEBIT CARD PURCHASE SUBWAY 0448 05-11 WASHINGTON DC 6901',
#      '7.30'],
#     ['05/15',
#      'DEBIT CARD PURCHASE-PIN 05-12-20 BALTIMORE MD 6901 SHELL SERVICE STATION',
#      '16.47'],
#     ['05/15',
#      'DEBIT CARD PURCHASE-PIN 05-12-20 BALTIMORE MD 6901 7-ELEVEN',
#      '7.22'],
#     ['05/15',
#      'DEBIT CARD PURCHASE OCEAN BEAUTY 05-12 TEMPLE HILLS MD 6901',
#      '6.35'],
#     ['05/15',
#      'DEBIT CARD PURCHASE SUBWAY 0448 05-12 WASHINGTON DC 6901',
#      '10.60'],
#     ['05/15',
#      'DEBIT CARD PURCHASE Q & Q CLEANERS 05-13 WASHINGTON DC 6901',
#      '13.98'],
#     ['05/15',
#      'DEBIT CARD PURCHASE-PIN 05-13-20 WASHINGTON DC 6901 SAFEWAY 2808',
#      '21.83'],
#     ['05/15',
#      'DEBIT CARD PURCHASE-PIN 05-13-20 DISTRICT HEIG MD 6901 ROYAL FARMS #287',
#      '10.00'],
#     ['05/15',
#      'DEBIT CARD PURCHASE CHECKERS #5936 05-13 CAMP SPRINGS MD 6901',
#      '19.48'],
#     ['05/15',
#      'DEBIT CARD PURCHASE-PIN 05-13-20 SUITLAND MD 6901 AUTOZONE 6539 4803 ALLEN',
#      '19.05'],
#     ['05/15',
#      'DEBIT CARD PURCHASE-PIN 05-14-20 DISTRICT HEIG MD 6901 ROYAL FARMS #269',
#      '22.36'],
#     ['05/16',
#      'DEBIT CARD PURCHASE METRO PCS 5600 05-14 201-538-1876 MD 6901',
#      '114.30'],
#     ['05/16',
#      "DEBIT CARD PURCHASE AMZN Mktp US'MS6JM 05-15 Amzn.com/bill WA 6901",
#      '9.53'],
#     ['05/16',
#      'DEBIT CARD PURCHASE-PIN 05-15-20 WASHINGTON DC 6901 SAFEWAY 2808',
#      '44.42'],
#     ['05/16', 'USCAP PYMT U.S. CAPITAL 9308 RICARDO BROUGHTON', '3.00'],
#     ['05/16', 'INTERNET PAYMENT ePay Fortiva MC PMT FORTIVA MC PMT', '150.00'],
#     ['05/16', 'USCAP PYMT U.S. CAPITAL 9308 RICARDO BROUGHTON', '193.22'],
#     ['05/17',
#      'DEBIT CARD PURCHASE AMZN Mktp US*MYOTK 05-16 Amzn.com/bill WA 6901',
#      '169.48'],
#     ['05/17',
#      'DEBIT CARD PURCHASE SHAKE SHACK 1136 05-15 646-747-7200 MD 6901',
#      '22.43'],
#     ['05/17',
#      'DEBIT CARD PURCHASE-PIN 05-16-20 BALTIMORE MD 6901 RUSSELL STREET C',
#      '20.00']]},
#   {'header': ['DATE', 'DESCRIPTION', 'AMOUNT ($)'],
#    'rows': [['04/29',
#      'PAYROLL MJ VALET. LLC 39-0 RICARDO BROUGHTON',
#      '1651.82'],
#     ['05/01', '8662580165 VBS BetterDay 61cd Ricardo Broughton', '1150.00'],
#     ['05/04', 'PAYMENT FROM BELLA”S BAKERY INV#202448', '2186.48'],
#     ['05/12', 'PAYROLL MJ VALET, LLC 39-0 RICARDO BROUGHTON', '1651.82'],
#     ['05/15', 'BELLA’S BAKERY INV#102448', '2168.48'],
#     ['05/15', '8662580165 VBS BetterDay 80cd Ricardo Broughton', '1200.00']]},
#   {'header': ['Date', 'DESCRIPTION', 'AMOUNT ($)'],
#    'rows': [['04/26',
#      'BB&T 24 CASH WITHDRAWAL 05-25-20 6901 CLINTON-MAIN CLINTON MD',
#      '20.00'],
#     ['04/29',
#      'BB&T 24 CASH WITHDRAWAL 05-29-20 6901 CLINTON-MAIN CLINTON MD',
#      '260.00'],
#     ['05/12',
#      'BB&T M-APP TRANSFER TRANSFER TO CHECKING 1090001004290 05-12-20',
#      '160.00']]}]}
